# %%
from matplotlib import font_manager, pyplot as plt

# 查找系统中所有可用的Times New Roman字体的路径
times_new_roman = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# 从列表中找到一个指定的字体名称，并确保字体能支持加粗
t_nr_path = [f for f in times_new_roman if 'Times New Roman' in f and 'Bold' in f]

if t_nr_path:
    # 如果找到了Times New Roman Bold字体，设置为默认字体
    prop = font_manager.FontProperties(fname=t_nr_path[0])
    plt.rcParams['font.family'] = prop.get_name()
    plt.rcParams['font.weight'] = 'bold'  # 设置字体为加粗
else:
    # 如果没有找到加粗的Times New Roman，尝试设置为普通的Times New Roman并加粗
    t_nr_path = [f for f in times_new_roman if 'Times New Roman' in f]
    if t_nr_path:
        prop = font_manager.FontProperties(fname=t_nr_path[0])
        plt.rcParams['font.family'] = prop.get_name()
        plt.rcParams['font.weight'] = 'bold'
    else:
        # 如果没有找到Times New Roman，使用默认的衬线字体并设置为加粗
        plt.rcParams['font.family'] = 'serif'
        plt.rcParams['font.weight'] = 'bold'

# %%
# AUC
import matplotlib.pyplot as plt  
import numpy as np
  
# 定义指纹类型和对应的数值  
fingerprints = ['APFPs', 'AvalonFPs', 'ECFPs', 'FCFPs', 'MACCS', 'PubchemFPs']  
values = [0.913625, 0.92125, 0.924, 0.923, 0.914875, 0.923]  
colors = ['#86B6F6'] 
# 绘制水平条形图  
plt.barh(fingerprints, values, color=colors, edgecolor='black')  
plt.rc('axes', linewidth=2)  #线宽
# 设置y轴坐标标签  
plt.yticks(range(len(fingerprints)), fingerprints, fontsize=15)  
# 添加标题和坐标轴标签  
plt.title('AUC-ROC',fontweight='bold', fontsize=16)  
  # 设置x轴的范围和刻度  
plt.xlim(0.9, 0.93)  # 设置x轴的范围  
plt.xticks(np.arange(0.9, 0.93, 0.009), fontsize=15)  # 设置x轴的刻度（使用numpy的arange函数需要导入numpy库）   
# 显示网格，设置为虚线，并且放在底层  
#plt.grid(linestyle='--', alpha=0.4, zorder=0)  # alpha控制网格线透明度 
# 显示网格  
#plt.grid(axis='x', alpha=0.75)  # 仅显示x轴网格  
  
# 显示图表  
plt.tight_layout()
plt.savefig("AUC.svg", format='svg', bbox_inches="tight",dpi=600)
plt.show()

# %%
# Acc
import matplotlib.pyplot as plt  
import numpy as np
  
# 定义指纹类型和对应的数值  
fingerprints = ['APFPs', 'AvalonFPs', 'ECFPs', 'FCFPs', 'MACCS', 'PubchemFPs']  
values = [0.832375, 0.847375, 0.853, 0.85025, 0.839875, 0.84225]  
colors = ['#86B6F6'] 
# 绘制水平条形图  
plt.barh(fingerprints, values, color=colors, edgecolor='black')    
# 设置y轴坐标标签  
plt.yticks(range(len(fingerprints)), fingerprints, fontsize=15)  
# 添加标题和坐标轴标签  
plt.title('Acc',fontweight='bold', fontsize=16)  
  # 设置x轴的范围和刻度  
plt.xlim(0.83, 0.855)  # 设置x轴的范围  
plt.xticks(np.arange(0.83, 0.86, 0.01), fontsize=15)  # 设置x轴的刻度（使用numpy的arange函数需要导入numpy库）    
# 显示网格，设置为虚线，并且放在底层  
#plt.grid(linestyle='--', alpha=0.4, zorder=0)  # alpha控制网格线透明度 
# 显示网格  
#plt.grid(axis='x', alpha=0.75)  # 仅显示x轴网格  
  
# 显示图表  
#plt.show()
plt.tight_layout()
plt.savefig("Acc.svg", format='svg', bbox_inches="tight",dpi=600)
plt.show()

# %%
# Sen
import matplotlib.pyplot as plt  
import numpy as np
  
# 定义指纹类型和对应的数值  
fingerprints = ['APFPs', 'AvalonFPs', 'ECFPs', 'FCFPs', 'MACCS', 'PubchemFPs']  
values = [0.82775, 0.84275, 0.848, 0.84225, 0.83525, 0.837625]  
colors = ['#86B6F6'] 
# 绘制水平条形图  
plt.barh(fingerprints, values, color=colors, edgecolor='black')    
# 设置y轴坐标标签  
plt.yticks(range(len(fingerprints)), fingerprints, fontsize=15)  
# 添加标题和坐标轴标签  
plt.title('Sen',fontweight='bold', fontsize=16)  
  # 设置x轴的范围和刻度  
plt.xlim(0.82, 0.85)  # 设置x轴的范围  
plt.xticks(np.arange(0.82, 0.85, 0.01), fontsize=15)  # 设置x轴的刻度（使用numpy的arange函数需要导入numpy库）   
# 显示网格，设置为虚线，并且放在底层  
#plt.grid(linestyle='--', alpha=0.4, zorder=0)  # alpha控制网格线透明度 
# 显示网格  
#plt.grid(axis='x', alpha=0.75)  # 仅显示x轴网格  
  
# 显示图表  
#plt.show()
plt.tight_layout()
plt.savefig("Sen.svg", format='svg', bbox_inches="tight",dpi=600)
plt.show()

# %%
# Spe
import matplotlib.pyplot as plt  
import numpy as np
  
# 定义指纹类型和对应的数值  
fingerprints = ['APFPs', 'AvalonFPs', 'ECFPs', 'FCFPs', 'MACCS', 'PubchemFPs']  
values = [0.879, 0.897125, 0.889, 0.899, 0.889, 0.887]  
colors = ['#86B6F6'] 
# 绘制水平条形图  
plt.barh(fingerprints, values, color=colors, edgecolor='black')    
# 设置y轴坐标标签  
plt.yticks(range(len(fingerprints)), fingerprints, fontsize=15)  
# 添加标题和坐标轴标签  
plt.title('Spe',fontweight='bold', fontsize=16)  
  # 设置x轴的范围和刻度  
plt.xlim(0.87, 0.90)  # 设置x轴的范围  
plt.xticks(np.arange(0.87, 0.90, 0.01), fontsize=15)  # 设置x轴的刻度（使用numpy的arange函数需要导入numpy库）   
# 显示网格，设置为虚线，并且放在底层  
#plt.grid(linestyle='--', alpha=0.4, zorder=0)  # alpha控制网格线透明度 
# 显示网格  
#plt.grid(axis='x', alpha=0.75)  # 仅显示x轴网格  
  
# 显示图表  
#plt.show()
plt.tight_layout()
plt.savefig("Spe.svg", format='svg', bbox_inches="tight",dpi=600)
plt.show()

# %%
# F1
import matplotlib.pyplot as plt  
import numpy as np
  
# 定义指纹类型和对应的数值  
fingerprints = ['APFPs', 'AvalonFPs', 'ECFPs', 'FCFPs', 'MACCS', 'PubchemFPs']  
values = [0.829625, 0.845, 0.85, 0.845, 0.83725, 0.83975]  
colors = ['#86B6F6'] 
# 绘制水平条形图  
plt.barh(fingerprints, values, color=colors, edgecolor='black')    
# 设置y轴坐标标签  
plt.yticks(range(len(fingerprints)), fingerprints, fontsize=15)  
# 添加标题和坐标轴标签  
plt.title('F1',fontweight='bold', fontsize=16)  
  # 设置x轴的范围和刻度  
plt.xlim(0.82, 0.855)  # 设置x轴的范围  
plt.xticks(np.arange(0.82, 0.855, 0.01), fontsize=15)  # 设置x轴的刻度（使用numpy的arange函数需要导入numpy库）   
# 显示网格，设置为虚线，并且放在底层  
#plt.grid(linestyle='--', alpha=0.4, zorder=0)  # alpha控制网格线透明度 
# 显示网格  
#plt.grid(axis='x', alpha=0.75)  # 仅显示x轴网格  
  
# 显示图表  
#plt.show()
plt.tight_layout()
plt.savefig("F1.svg", format='svg', bbox_inches="tight",dpi=600)
plt.show()

# %%
# MCC
import matplotlib.pyplot as plt  
import numpy as np
  
# 定义指纹类型和对应的数值  
fingerprints = ['APFPs', 'AvalonFPs', 'ECFPs', 'FCFPs', 'MACCS', 'PubchemFPs']  
values = [0.662375, 0.694, 0.693375, 0.705125, 0.678125, 0.681875]  
colors = ['#86B6F6'] 
# 绘制水平条形图  
plt.barh(fingerprints, values, color=colors, edgecolor='black')    
# 设置y轴坐标标签  
plt.yticks(range(len(fingerprints)), fingerprints, fontsize=15)  
# 添加标题和坐标轴标签  
plt.title('MCC',fontweight='bold', fontsize=16)  
  # 设置x轴的范围和刻度  
plt.xlim(0.65, 0.71)  # 设置x轴的范围  
plt.xticks(np.arange(0.65, 0.71, 0.01), fontsize=15)  # 设置x轴的刻度（使用numpy的arange函数需要导入numpy库）   
# 显示网格，设置为虚线，并且放在底层  
#plt.grid(linestyle='--', alpha=0.4, zorder=0)  # alpha控制网格线透明度 
# 显示网格  
#plt.grid(axis='x', alpha=0.75)  # 仅显示x轴网格  
  
# 显示图表  
#plt.show()
plt.tight_layout()
plt.savefig("MCC.svg", format='svg', bbox_inches="tight",dpi=600)
plt.show()
