# %%
import os
import pandas as pd

# %%
# 检查当前工作目录
current_directory = os.getcwd()
print("当前工作目录:", current_directory)
# Out:
# 当前工作目录: /home/md06/public/jupytercode/kxy/1-数据集568/数据处理

# %%
# 使用pandas的read_csv函数加载CSV文件
df = pd.read_csv("chembl-568.csv")

# %%
# 显示DataFrame的前几行以确保数据被正确加载
df.head()
# Out:
#   Molecule ChEMBL ID  Molecular Weight  \
# 0      CHEMBL4460859            376.16
# 1       CHEMBL330432            410.60
# 2       CHEMBL370164            493.95
# 3        CHEMBL99707            344.17
# 4       CHEMBL194294            432.45
#
#                                               Smiles  Standard_Value  \
# 0  Nc1ncnc2c1c(I)nn2[C@@H]1C[C@H](N)[C@@H](O)[C@H]1O            0.06
# 1  NC[C@H]1O[C@@H](n2cc(I)c3c(Cl)ncnc32)[C@H](O)[...            0.10
# 2  C[C@H]1O[C@@H](n2cc(-c3ccccc3)c3c(NCC(=O)Nc4cc...            0.20
# 3  NC[C@H]1O[C@@H](n2cc(Br)c3c(N)ncnc32)[C@H](O)[...            0.20
# 4  O[C@H]1[C@H](n2cc(-c3ccccc3)c3c(Nc4ccc(F)cc4)n...            0.30
#
#   Standard Units Target Organism  \
# 0             nM    Homo sapiens
# 1             nM    Homo sapiens
# 2             nM    Homo sapiens
# 3             nM    Homo sapiens
# 4             nM    Homo sapiens
#
#                                  Standardized_SMILES
# ...

# %%
bioactivity_class = []#对IC50值进行分类
for i in df.Standard_Value:
    if float(i) > 300:
        bioactivity_class.append("0")
    elif float(i) <= 300:
        bioactivity_class.append("1")

# %%
mol_cid = []
for i in df["Molecule ChEMBL ID"]:
    mol_cid.append(i)

# %%
canonical_smiles = []
for i in df["Standardized_SMILES"]:
    canonical_smiles.append(i)

# %%
standard_value = []
for i in df["Standard_Value"]:
    standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4460859                    Nc1ncnc2c1c(I)nn2C1CC(N)C(O)C1O
# 1         CHEMBL330432                NCC1OC(n2cc(I)c3c(Cl)ncnc32)C(O)C1O
# 2         CHEMBL370164  CC1OC(n2cc(-c3ccccc3)c3c(NCC(=O)Nc4ccc(Cl)cc4)...
# 3          CHEMBL99707                NCC1OC(n2cc(Br)c3c(N)ncnc32)C(O)C1O
# 4         CHEMBL194294  OC1C(n2cc(-c3ccccc3)c3c(Nc4ccc(F)cc4)ncnc32)OC...
# ..                 ...                                                ...
# 563       CHEMBL612193       [N-]=[N+]=NCC1OC(n2cc(I)c3c(N)ncnc32)C(O)C1O
# 564       CHEMBL612189      [N-]=[N+]=NCC1OC(n2cc(I)c3c(Cl)ncnc32)C(O)C1O
# 565       CHEMBL611880                 CC1OC(n2cc(I)c3c(Cl)ncnc32)C(O)C1O
# 566       CHEMBL607751                NCC1OC(n2cc(Br)c3c(N)ncnc32)C(O)C1O
# 567       CHEMBL610115                NCC1OC(n2cc(I)c3c(Cl)ncnc32)C(O)C1O
#
#     bioactivity_class  standard_value
# 0                   1    6.000000e-02
# ...

# %%
df3.to_csv('ADK-chembl-568.csv', index=False)#到这一步即可
